# %% [markdown]
# # Plotting Growth Rate

# %%
# %load_ext autoreload
# %autoreload 2


from tdm.analysis import Analysis
from tdm.plot.two_cells import plot_growth_rate

ana = Analysis.load("fm.pkl")
        
plot_growth_rate(
    ana,
    kde_bw=0.35,
    cell_a_rbf_gamma=1.2,
    cell_b_rbf_gamma=0.3,
);
