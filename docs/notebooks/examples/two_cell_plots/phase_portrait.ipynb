# %% [markdown]
# # Plotting a 2D Phase Portrait

# %%
from tdm.analysis import Analysis
from tdm.plot.two_cells import plot_phase_portrait

ana = Analysis.load("fm.pkl")
plot_phase_portrait(ana)
