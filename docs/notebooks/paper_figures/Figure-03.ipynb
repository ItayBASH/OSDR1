# %% [markdown]
# # Figure 3 - Fibroblast Macrophage Dynamics

# %%
from tdm.publications.first.figures.f3 import fig_3a, fig_3def, fig_3g, fig_3h

# %% [markdown]
# # Fig 3A: Neighbor cell counts are strong predictors of division probability

# %%
fig_3a()
# Out:
# 1/5 Constructing tissues [V]
# 2/5 Counting cell-neighbors [V]
# 3/5 Filtering cell-types [V]
# 4/5 Transforming features [V]
# 5/5 Fitting a model [V]

# %% [markdown]
# ## Fig 3D,E,F:
#
# * Fibroblast-Macrophage Phase portrait (left)
# * Fibroblast growth rate (middle)
# * Macrophage growth rate (right)

# %%
fig_3def()

# %% [markdown]
# ## Fig 3G: Tumor-cells support the hot-fibrosis fixed-point

# %%
fig_3g()

# %% [markdown]
# # Hot Fibrosis is associated with poor prognosis

# %%
fig_3h()
# Out:
# Median survival time for hot-fibrosis: 132.566666666667
# Median survival time for cold-fibrosis: 192.266666666667
