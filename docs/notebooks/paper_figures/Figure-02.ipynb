# %% [markdown]
# # Figure 2 - OSDR reproduces neighborhood dynamics of known models

# %%
from tdm.publications.first.figures.f2 import fig_2d

# %% [markdown]
# For an analysis of the accuracy of reconstructed fixed-points and basins of attraction, please refer to supplementary figures S2G-O.

# %%
fig_2d()
# Out:
# Note: simulations are computationally intensive and may take several minutes to run (>15 minutes on some systems)
